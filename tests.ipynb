# %%
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local', 'messageboard']

# %%
db = client['rohlik']

# %%
articles = db['products']

# %%
db.list_collection_names()
# Out:
# ['products']

# %%
import datetime
post = {"author": "Mikes",
        "text": "My first blog post!",
        "tags": ["mongodb", "python", "pymongo"],
        "date": datetime.datetime.utcnow()}

# %%
articles.insert_one(post)

# %%
articles.drop()

# %%
from pprint import pprint
for article in articles.find({}):
    pprint(article)
# Out:
# {'_id': ObjectId('5bbcb6c9374e2f05c585e84c'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 563000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1302691/1302691-1501768996-260.jpg',
#  'name': 'Merhautovo pekařství Rohlík Benátecký bez posypu',
#  'price': '3,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1302691-merhautovo-pekarstvi-rohlik-benatecky-bez-posypu'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e84d'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 651000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1286399/1286399-1432042251-260.jpg',
#  'name': 'Pekárna Brod Rohlík jemný',
#  'price': '1,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1286399-pekarna-brod-rohlik-jemny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e84e'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 653000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1302703/1302703-1497275311-260.jpg',
#  'name': 'Merhautovo pekařství Chléb žitný',
#  'price': '24,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1302703-merhautovo-pekarstvi-chleb-zitny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e84f'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 656000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1303345/1303345-1497275742-260.jpg',
#  'name': 'Merhautovo pekařství Loupák',
#  'price': '8,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1303345-merhautovo-pekarstvi-loupak'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e850'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 658000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1314059/1314059-1524045553-260.jpg',
#  'name': 'Pekárna Kabát Celozrnná houska',
#  'price': '8,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1314059-pekarna-kabat-celozrnna-houska'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e851'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 661000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1329307/1329307-1505201423-260.jpg',
#  'name': 'My Cake Preclík louhovaný',
#  'price': '11,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1329307-my-cake-preclik-louhovany'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e852'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 663000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1292071/1292071-1501768549-260.jpg',
#  'name': 'Merhautovo pekařství Pivařský rohlík',
#  'price': '4,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1292071-merhautovo-pekarstvi-pivarsky-rohlik'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e853'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 666000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1335597/1335597-1517560228-260.jpg',
#  'name': 'Bageta velká světlá',
#  'price': '14,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1335597-bageta-velka-svetla'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e854'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 668000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/717957/717957-1498808225-260.jpg',
#  'name': 'Kaiserka natural',
#  'price': '3,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=717957-kaiserka-natural'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e855'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 671000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310539/1310539-1524045432-260.jpg',
#  'name': 'Pekárna Kabát Brusinková bageta',
#  'price': '24,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310539-pekarna-kabat-brusinkova-bageta'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e856'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 673000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/717953/717953-1498808178-260.jpg',
#  'name': 'Kaiserka cereální',
#  'price': '3,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=717953-kaiserka-cerealni'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e857'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 675000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1303313/1303313-1497275406-260.jpg',
#  'name': 'Merhautovo pekařství Chléb piknik kulatý',
#  'price': '21,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1303313-merhautovo-pekarstvi-chleb-piknik-kulaty'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e858'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 677000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1302693/1302693-1501667783-260.jpg',
#  'name': 'Merhautovo pekařství Houska ražená bez posypu',
#  'price': '3,40\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1302693-merhautovo-pekarstvi-houska-razena-bez-posypu'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e859'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 680000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/729507/729507-1488986075-260.jpg',
#  'name': 'REJ Kukuřičné tyčky',
#  'price': '21,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=729507-rej-kukuricne-tycky'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e85a'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 683000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1290497/1290497-1523616160-260.jpg',
#  'name': 'Penam chléb toustový máslový',
#  'price': '29,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1290497-penam-chleb-toustovy-maslovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e85b'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 685000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1311615/1311615-1466068427-260.jpg',
#  'name': 'Antica Cantina Wrap Tortillas 25cm 6ks',
#  'price': '',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1311615-antica-cantina-wrap-tortillas-25cm-6ks'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e85c'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 688000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1340589/1340589-1527857023-260.jpg',
#  'name': 'My Cake Bulka řemeslná světlá',
#  'price': '8,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1340589-my-cake-bulka-remeslna-svetla'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e85d'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 690000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1316135/1316135-1495633335-260.jpg',
#  'name': 'Rolka máslová čokoládová',
#  'price': '11,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1316135-rolka-maslova-cokoladova'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e85e'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 693000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1296479/1296479-1508484832-260.jpg',
#  'name': 'La Lorraine Kornbageta',
#  'price': '10,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1296479-la-lorraine-kornbageta'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e85f'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 695000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310553/1310553-1508098682-260.jpg',
#  'name': 'Pekárna Kabát Hamburgerová houska sezam',
#  'price': '18,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310553-pekarna-kabat-hamburgerova-houska-sezam'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e860'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 698000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1333383/1333383-1515594402-260.jpg',
#  'name': 'Ibis Bagety k dopečení 6ks',
#  'price': '24,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1333383-ibis-bagety-k-dopeceni-6ks'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e861'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 700000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1314821/1314821-1495631592-260.jpg',
#  'name': 'Pekárna Brod Žitný chléb',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1314821-pekarna-brod-zitny-chleb'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e862'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 704000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1287591/1287591-1497275005-260.jpg',
#  'name': 'Merhautovo pekařství  Houska Corny',
#  'price': '7,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1287591-merhautovo-pekarstvi-houska-corny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e863'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 706000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1323919/1323919-1504083494-260.jpg',
#  'name': 'Klasa Linecké rohlíčky polomáčené s ovocnou náplní',
#  'price': '24,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1323919-klasa-linecke-rohlicky-polomacene-s-ovocnou-naplni'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e864'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 709000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1314061/1314061-1470908573-260.jpg',
#  'name': 'Pekárna Kabát Kabátův Cvrček',
#  'price': '39,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1314061-pekarna-kabat-kabatuv-cvrcek'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e865'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 711000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1328485/1328485-1506889065-260.jpg',
#  'name': 'Pekárna Kabát Tvarohový mazánek',
#  'price': '16,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1328485-pekarna-kabat-tvarohovy-mazanek'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e866'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 713000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1338997/1338997-1533542972-260.jpg',
#  'name': 'Rohlik.cz Náš rohlík - čerstvě upečeno u nás',
#  'price': '4,50\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1338997-rohlik-cz-nas-rohlik-cerstve-upeceno-u-nas'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e867'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 716000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1328483/1328483-1506889000-260.jpg',
#  'name': 'Pekárna Kabát Ořechový mazánek',
#  'price': '16,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1328483-pekarna-kabat-orechovy-mazanek'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e868'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 718000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1297903/1297903-1441812848-260.jpg',
#  'name': 'Penam chléb Fit Den Večerní chlebík',
#  'price': '39,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1297903-penam-chleb-fit-den-vecerni-chlebik'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e869'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 720000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1315859/1315859-1524127438-260.jpg',
#  'name': 'Pan Casa Toustový chléb tmavý cereální',
#  'price': '29,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1315859-pan-casa-toustovy-chleb-tmavy-cerealni'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e86a'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 722000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1286405/1286405-1501666064-260.jpg',
#  'name': 'Pekárna Brod Houska',
#  'price': '1,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1286405-pekarna-brod-houska'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e86b'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 725000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310537/1310537-1524045249-260.jpg',
#  'name': 'Pekárna Kabát 7zrnná bageta',
#  'price': '16,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310537-pekarna-kabat-7zrnna-bageta'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e86c'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 728000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1322329/1322329-1489139960-260.jpg',
#  'name': 'Penam Chléb FIT žitný celozrnný',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1322329-penam-chleb-fit-zitny-celozrnny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e86d'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 730000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1316131/1316131-1495630558-260.jpg',
#  'name': 'Dýňová bulka',
#  'price': '8,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1316131-dynova-bulka'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e86e'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 733000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1316133/1316133-1473843863-260.jpg',
#  'name': 'Bulka z kamenné pece se slunečnicí',
#  'price': '6,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1316133-bulka-z-kamenne-pece-se-slunecnici'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e86f'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 735000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1315853/1315853-1524127046-260.jpg',
#  'name': 'Pan Casa Toustový chléb z tvrdozrnné pšenice s olivovým olejem',
#  'price': '29,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1315853-pan-casa-toustovy-chleb-z-tvrdozrnne-psenice-s-olivovym-olejem'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e870'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 738000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310547/1310547-1501768464-260.jpg',
#  'name': 'Pekárna Kabát Staročeský Kabátův pecen 1/4',
#  'price': '39,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310547-pekarna-kabat-starocesky-kabatuv-pecen-1-4'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e871'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 740000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1311621/1311621-1466068711-260.jpg',
#  'name': 'Antica Cantina Tortilla 20cm 8ks',
#  'price': '69,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1311621-antica-cantina-tortilla-20cm-8ks'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e872'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 743000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1325331/1325331-1496128342-260.jpg',
#  'name': 'My Cake Bageta z kamenné pece',
#  'price': '26,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1325331-my-cake-bageta-z-kamenne-pece'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e873'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 745000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/8791/d9/729623-1424201213-260.jpg',
#  'name': 'RACIO Knäckebrot žitný s vlákninou',
#  'price': '39,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=729623-racio-knackebrot-zitny-s-vlakninou'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e874'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 747000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1317323/1317323-1476805783-260.jpg',
#  'name': 'L´chefs baguettes Bagety k dopečení 6 ks',
#  'price': '29,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1317323-l-chefs-baguettes-bagety-k-dopeceni-6-ks'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e875'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 750000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1302695/1302695-1497275184-260.jpg',
#  'name': 'Merhautovo pekařství Chléb kvasový šiška',
#  'price': '31,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1302695-merhautovo-pekarstvi-chleb-kvasovy-siska'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e876'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 753000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1332577/1332577-1514374802-260.jpg',
#  'name': 'Mestemacher Trvanlivý žitný chléb celozrnný se slunečnicovými semeny',
#  'price': '34,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1332577-mestemacher-trvanlivy-zitny-chleb-celozrnny-se-slunecnicovymi-semeny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e877'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 755000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1340591/1340591-1527858282-260.jpg',
#  'name': 'My Cake Bulka řemeslná tmavá',
#  'price': '8,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1340591-my-cake-bulka-remeslna-tmava'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e878'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 757000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1323905/1323905-1504083564-260.jpg',
#  'name': 'Klasa Linecké rohlíčky polomáčené',
#  'price': '',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1323905-klasa-linecke-rohlicky-polomacene'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e879'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 760000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1321697/1321697-1501770498-260.jpg',
#  'name': 'Penam Chléb FIT žitno- slunečnicový celozrnný',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1321697-penam-chleb-fit-zitno-slunecnicovy-celozrnny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e87a'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 762000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1294979/1294979-1495633534-260.jpg',
#  'name': 'Muffin čokoládový',
#  'price': '29,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1294979-muffin-cokoladovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e87b'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 764000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1329163/1329163-1504871258-260.jpg',
#  'name': 'My Cake Kostka slunečnicová',
#  'price': '7,50\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1329163-my-cake-kostka-slunecnicova'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e87c'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 767000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1328469/1328469-1505685950-260.jpg',
#  'name': 'Pekárna Kabát Tradiční koláč mák',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1328469-pekarna-kabat-tradicni-kolac-mak'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e87d'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 769000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310565/1310565-1476133698-260.jpg',
#  'name': 'Pekárna Kabát Kobliha jahodová',
#  'price': '11,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310565-pekarna-kabat-kobliha-jahodova'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e87e'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 771000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1328463/1328463-1505685885-260.jpg',
#  'name': 'Pekárna Kabát Tradiční koláč tvaroh',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1328463-pekarna-kabat-tradicni-kolac-tvaroh'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e87f'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 774000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1302701/1302701-1497275267-260.jpg',
#  'name': 'Merhautovo pekařství Chléb Sedlácký',
#  'price': '34,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1302701-merhautovo-pekarstvi-chleb-sedlacky'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e880'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 777000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310541/1310541-1463555438-260.jpg',
#  'name': 'Pekárna Kabát Dýňový trojhránek',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310541-pekarna-kabat-dynovy-trojhranek'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e881'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 779000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310551/1310551-1463756643-260.jpg',
#  'name': 'Pekárna Kabát Škvarková placka',
#  'price': '18,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310551-pekarna-kabat-skvarkova-placka'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e882'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 781000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1321821/1321821-1501769771-260.jpg',
#  'name': 'Merhautovo pekařství Kornspitz',
#  'price': '9,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1321821-merhautovo-pekarstvi-kornspitz'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e883'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 784000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310207/1310207-1523616116-260.jpg',
#  'name': 'Penam chléb toustový světlý',
#  'price': '22,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310207-penam-chleb-toustovy-svetly'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e884'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 786000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1294981/1294981-1495633452-260.jpg',
#  'name': 'Muffin borůvkový',
#  'price': '29,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1294981-muffin-boruvkovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e885'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 788000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1333385/1333385-1515594930-260.jpg',
#  'name': 'Ibis Bagety k dopečení 4 ks',
#  'price': '24,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1333385-ibis-bagety-k-dopeceni-4-ks'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e886'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 791000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1293497/1293497-1495635392-260.jpg',
#  'name': 'Kuchenmeister Bábovka mramorová',
#  'price': '49,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1293497-kuchenmeister-babovka-mramorova'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e887'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 793000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/718081/718081-1513329385-260.jpg',
#  'name': 'Český pekař Strouhanka',
#  'price': '14,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=718081-cesky-pekar-strouhanka'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e888'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 796000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1302699/1302699-1501769139-260.jpg',
#  'name': 'Merhautovo pekařství  Chléb Podmáslový',
#  'price': '29,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1302699-merhautovo-pekarstvi-chleb-podmaslovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e889'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 798000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1316137/1316137-1473845587-260.jpg',
#  'name': 'Šnek máslový s náplní vanilkový krém a rozinky',
#  'price': '11,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1316137-snek-maslovy-s-naplni-vanilkovy-krem-a-rozinky'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e88a'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 801000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1329149/1329149-1504862600-260.jpg',
#  'name': 'My Cake Kostka vícezrnná',
#  'price': '7,50\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1329149-my-cake-kostka-vicezrnna'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e88b'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 803000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310577/1310577-1494792003-260.jpg',
#  'name': 'Pekárna Kabát Moravský koláč jahoda',
#  'price': '27,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310577-pekarna-kabat-moravsky-kolac-jahoda'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e88c'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 806000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/729695/729695-1495787453-260.jpg',
#  'name': 'Wasa Original chléb křupavý žitný',
#  'price': '49,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=729695-wasa-original-chleb-krupavy-zitny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e88d'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 808000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/720941/720941-1496220509-260.jpg',
#  'name': '7Days Croissant kakao',
#  'price': '12,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=720941-7days-croissant-kakao'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e88e'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 811000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1321155/1321155-1495716928-260.jpg',
#  'name': 'Bonavita Křehké plátky pohankové',
#  'price': '12,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1321155-bonavita-krehke-platky-pohankove'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e88f'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 813000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1298995/1298995-1523616035-260.jpg',
#  'name': 'Penam Chléb toustový tmavý vícezrnný',
#  'price': '22,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1298995-penam-chleb-toustovy-tmavy-vicezrnny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e890'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 815000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1321699/1321699-1487863537-260.jpg',
#  'name': 'Penam chléb Fit den Sporty chléb',
#  'price': '34,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1321699-penam-chleb-fit-den-sporty-chleb'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e891'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 817000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1303341/1303341-1501766288-260.jpg',
#  'name': 'Merhautovo pekařství Koláč tvarohový',
#  'price': '17,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1303341-merhautovo-pekarstvi-kolac-tvarohovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e892'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 819000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1315051/1315051-1494791954-260.jpg',
#  'name': 'Pekárna Kabát Moravský koláč švestka',
#  'price': '27,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1315051-pekarna-kabat-moravsky-kolac-svestka'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e893'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 822000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1339015/1339015-1524746282-260.jpg',
#  'name': 'Merhautovo pekařství Hamburgerová bulka klasik se sezamem',
#  'price': '9,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1339015-merhautovo-pekarstvi-hamburgerova-bulka-klasik-se-sezamem'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e894'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 824000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1316579/1316579-1474991288-260.jpg',
#  'name': 'RACIO Knäckebrot žitný',
#  'price': '39,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1316579-racio-knackebrot-zitny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e895'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 826000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1298225/1298225-1522156133-260.jpg',
#  'name': 'Penam Super Sandwich světlý chléb pšeničný krájený',
#  'price': '36,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1298225-penam-super-sandwich-svetly-chleb-psenicny-krajeny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e896'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 828000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1316561/1316561-1474981490-260.jpg',
#  'name': 'RACIO RACIOLKY mléčnokakaové',
#  'price': '',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1316561-racio-raciolky-mlecnokakaove'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e897'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 831000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1314065/1314065-1470823142-260.jpg',
#  'name': 'Pekárna Kabát Rohlík vícezrnný',
#  'price': '11,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1314065-pekarna-kabat-rohlik-vicezrnny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e898'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 833000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1311277/1311277-1501770419-260.jpg',
#  'name': 'Kubík Štrúdlík jemné pečivo s jablečnou náplní',
#  'price': '4,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1311277-kubik-strudlik-jemne-pecivo-s-jablecnou-naplni'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e899'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 835000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/820313/820313-1501765789-260.jpg',
#  'name': '7Days Croissant family pack',
#  'price': '38,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=820313-7days-croissant-family-pack'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e89a'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 838000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1303327/1303327-1497275495-260.jpg',
#  'name': 'Merhautovo pekařství Koláč borůvkový',
#  'price': '17,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1303327-merhautovo-pekarstvi-kolac-boruvkovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e89b'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 840000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1314125/1314125-1501771191-260.jpg',
#  'name': 'DoDo Bezlepkový semínkový chléb',
#  'price': '89,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1314125-dodo-bezlepkovy-seminkovy-chleb'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e89c'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 843000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1321823/1321823-1497279012-260.jpg',
#  'name': 'Merhautovo pekařství Kostka čistozrnná',
#  'price': '64,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1321823-merhautovo-pekarstvi-kostka-cistozrnna'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e89d'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 845000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1332519/1332519-1513680286-260.jpg',
#  'name': 'My Cake CIABATTA',
#  'price': '8,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1332519-my-cake-ciabatta'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e89e'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 847000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1320033/1320033-1492004172-260.jpg',
#  'name': 'Donuter Boston Cream',
#  'price': '54,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1320033-donuter-boston-cream'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e89f'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 851000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1316563/1316563-1474982318-260.jpg',
#  'name': 'RACIO RACIOLKY jablko & skořice',
#  'price': '22,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1316563-racio-raciolky-jablko-skorice'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8a0'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 854000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1316649/1316649-1501771654-260.jpg',
#  'name': 'RACIO Free Style rajče a bazalka',
#  'price': '9,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1316649-racio-free-style-rajce-a-bazalka'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8a1'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 857000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1339019/1339019-1524747362-260.jpg',
#  'name': 'Merhautovo pekařství Chléb kvasový formový',
#  'price': '20,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1339019-merhautovo-pekarstvi-chleb-kvasovy-formovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8a2'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 861000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/718035/718035-1504598865-260.jpg',
#  'name': 'Penam Chléb zábrdovický balený krájený',
#  'price': '22,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=718035-penam-chleb-zabrdovicky-baleny-krajeny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8a3'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 863000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1331665/1331665-1510569561-260.jpg',
#  'name': 'Donut s kakaovou polevou a drcenými bonbony',
#  'price': '12,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1331665-donut-s-kakaovou-polevou-a-drcenymi-bonbony'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8a4'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 867000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1324879/1324879-1497279416-260.jpg',
#  'name': 'KOMPEK Chléb kladenský klas krájený',
#  'price': '17,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1324879-kompek-chleb-kladensky-klas-krajeny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8a5'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 871000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/720945/720945-1501770761-260.jpg',
#  'name': '7Days Croissant lískooříškový',
#  'price': '12,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=720945-7days-croissant-liskooriskovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8a6'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 874000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1311279/1311279-1501771911-260.jpg',
#  'name': 'Kubík Štrúdlík jemné pečivo s ovocnou náplní',
#  'price': '4,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1311279-kubik-strudlik-jemne-pecivo-s-ovocnou-naplni'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8a7'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 876000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/717803/717803-1495705459-260.jpg',
#  'name': 'Hradecká pekárna Chléb žitný balený krájený,',
#  'price': '29,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=717803-hradecka-pekarna-chleb-zitny-baleny-krajeny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8a8'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 879000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1330955/1330955-1508851104-260.jpg',
#  'name': 'Pekárna Kabát Houska šunková',
#  'price': '29,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1330955-pekarna-kabat-houska-sunkova'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8a9'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 882000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1326867/1326867-1501771976-260.jpg',
#  'name': 'Rice Up Celozrnné rýžové chlebíčky - s chia a Quinoa',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1326867-rice-up-celozrnne-ryzove-chlebicky-s-chia-a-quinoa'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8aa'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 884000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1340445/1340445-1527601671-260.jpg',
#  'name': 'KOMPEK Závin makový',
#  'price': '39,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1340445-kompek-zavin-makovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8ab'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 887000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/729591/729591-1495715882-260.jpg',
#  'name': 'RACIO Cornies se lněným semínkem',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=729591-racio-cornies-se-lnenym-seminkem'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8ac'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 889000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1332575/1332575-1514373432-260.jpg',
#  'name': 'Mestemacher Trvanlivý chléb vícezrnný s žitem, ječmenem a ovsem',
#  'price': '34,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1332575-mestemacher-trvanlivy-chleb-vicezrnny-s-zitem-jecmenem-a-ovsem'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8ad'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 893000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1303337/1303337-1497275610-260.jpg',
#  'name': 'Merhautovo pekařství Koláč makový',
#  'price': '17,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1303337-merhautovo-pekarstvi-kolac-makovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8ae'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 897000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1305587/1305587-1497275774-260.jpg',
#  'name': 'Merhautovo pekařství Brioška máslová',
#  'price': '11,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1305587-merhautovo-pekarstvi-brioska-maslova'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8af'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 900000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1311275/1311275-1501770823-260.jpg',
#  'name': 'Kubík Štrúdlík jemné pečivo s višňovo - jablečnou náplní',
#  'price': '4,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1311275-kubik-strudlik-jemne-pecivo-s-visnovo-jablecnou-naplni'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8b0'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 904000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310545/1310545-1463756684-260.jpg',
#  'name': 'Pekárna Kabát Ořechový chléb',
#  'price': '59,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310545-pekarna-kabat-orechovy-chleb'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8b1'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 908000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1323335/1323335-1504091157-260.jpg',
#  'name': 'Rice Up Celozrnné rýžové chipsy - s příchutí sýru',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1323335-rice-up-celozrnne-ryzove-chipsy-s-prichuti-syru'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8b2'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 911000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1330875/1330875-1524045338-260.jpg',
#  'name': 'Pekárna Kabát Brioška vaječná',
#  'price': '22,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1330875-pekarna-kabat-brioska-vajecna'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8b3'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 915000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310579/1310579-1494791885-260.jpg',
#  'name': 'Pekárna Kabát Moravský koláč mák',
#  'price': '27,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310579-pekarna-kabat-moravsky-kolac-mak'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8b4'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 917000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1314077/1314077-1501747225-260.jpg',
#  'name': 'Pekárna Kabát Mandlovka',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1314077-pekarna-kabat-mandlovka'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8b5'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 920000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1306127/1306127-1458049274-260.jpg',
#  'name': "Wasa Crisp'n Light Žitný knackebrot",
#  'price': '34,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1306127-wasa-crisp-n-light-zitny-knackebrot'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8b6'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 922000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1331453/1331453-1510050594-260.jpg',
#  'name': 'Ölz Vánočka',
#  'price': '49,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1331453-olz-vanocka'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8b7'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 925000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1323329/1323329-1490780522-260.jpg',
#  'name': 'Rice Up celozrnné rýžové chipsy - smetana a cibule',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1323329-rice-up-celozrnne-ryzove-chipsy-smetana-a-cibule'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8b8'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 927000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/729595/729595-1501772050-260.jpg',
#  'name': 'RACIO Cornies kukuřičné s mořskou solí',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=729595-racio-cornies-kukuricne-s-morskou-soli'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8b9'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 929000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1306191/1306191-1496735561-260.jpg',
#  'name': 'Santa Maria Tex Mex Original soft mexická pšeničná tortilla 20cm 8ks',
#  'price': '65,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1306191-santa-maria-tex-mex-original-soft-mexicka-psenicna-tortilla-20cm-8ks'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8ba'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 931000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/720931/720931-1496220746-260.jpg',
#  'name': '7Days Croissant double kakao+vanilka',
#  'price': '12,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=720931-7days-croissant-double-kakao-vanilka'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8bb'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 934000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1330867/1330867-1524045295-260.jpg',
#  'name': 'Pekárna Kabát Brioška šunková',
#  'price': '22,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1330867-pekarna-kabat-brioska-sunkova'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8bc'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 937000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310559/1310559-1463756750-260.jpg',
#  'name': 'Pekárna Kabát Čoko rohlík',
#  'price': '21,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310559-pekarna-kabat-coko-rohlik'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8bd'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 939000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1324847/1324847-1494517450-260.jpg',
#  'name': 'Ölz super soft sandwich toustový chléb',
#  'price': '32,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1324847-olz-super-soft-sandwich-toustovy-chleb'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8be'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 942000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310549/1310549-1475877026-260.jpg',
#  'name': 'Pekárna Kabát Rohlík kroucený',
#  'price': '6,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310549-pekarna-kabat-rohlik-krouceny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8bf'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 944000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1315053/1315053-1494792092-260.jpg',
#  'name': 'Pekárna Kabát Moravský koláč višňový',
#  'price': '27,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1315053-pekarna-kabat-moravsky-kolac-visnovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8c0'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 946000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1343607/1343607-1536128110-260.jpg',
#  'name': 'Penam Závin s náplní tvarohovou',
#  'price': '44,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1343607-penam-zavin-s-naplni-tvarohovou'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8c1'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 949000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1326871/1326871-1501772242-260.jpg',
#  'name': 'Rice Up Celozrnné rýžové chlebíčky - se 7 druhy semen',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1326871-rice-up-celozrnne-ryzove-chlebicky-se-7-druhy-semen'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8c2'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 951000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1323923/1323923-1491922782-260.jpg',
#  'name': 'Klasa Povidláčky',
#  'price': '29,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1323923-klasa-povidlacky'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8c3'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 953000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1324761/1324761-1494344895-260.jpg',
#  'name': 'Ölz super soft sandwich toustový chléb',
#  'price': '49,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1324761-olz-super-soft-sandwich-toustovy-chleb'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8c4'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 955000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1298223/1298223-1522156206-260.jpg',
#  'name': 'Penam Super Sandwich Celozrnný chléb pšeničný krájený',
#  'price': '39,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1298223-penam-super-sandwich-celozrnny-chleb-psenicny-krajeny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8c5'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 958000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1307267/1307267-1495644391-260.jpg',
#  'name': 'Můj dortík medový dort Caramelka',
#  'price': '149,00\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1307267-muj-dortik-medovy-dort-caramelka'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8c6'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 960000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1321679/1321679-1523616086-260.jpg',
#  'name': 'Penam chléb toustový světlý',
#  'price': '14,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1321679-penam-chleb-toustovy-svetly'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8c7'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 963000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1316139/1316139-1495633161-260.jpg',
#  'name': 'Kobliha s ovocnou náplní',
#  'price': '6,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1316139-kobliha-s-ovocnou-naplni'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8c8'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 965000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1307271/1307271-1495645006-260.jpg',
#  'name': 'Můj dortík Medový dort Zebra',
#  'price': '149,00\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1307271-muj-dortik-medovy-dort-zebra'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8c9'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 967000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1330943/1330943-1524045093-260.jpg',
#  'name': 'Pekárna Kabát Sladový preclík plněný',
#  'price': '39,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1330943-pekarna-kabat-sladovy-preclik-plneny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8ca'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 969000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1290487/1290487-1495631681-260.jpg',
#  'name': 'Penam Chléb Fit slunečnicový balený krájený',
#  'price': '39,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1290487-penam-chleb-fit-slunecnicovy-baleny-krajeny'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8cb'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 971000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1303927/1303927-1515144340-260.jpg',
#  'name': 'Country Life BIO Strouhanka kukuřičná',
#  'price': '',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1303927-country-life-bio-strouhanka-kukuricna'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8cc'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 973000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1339007/1339007-1524744627-260.jpg',
#  'name': 'Merhautovo pekařství Hamburgerová bulka mléčná se sezamem',
#  'price': '14,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1339007-merhautovo-pekarstvi-hamburgerova-bulka-mlecna-se-sezamem'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8cd'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 976000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1303343/1303343-1497275670-260.jpg',
#  'name': 'Merhautovo pekařství Koláč povidlový',
#  'price': '17,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1303343-merhautovo-pekarstvi-kolac-povidlovy'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8ce'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 978000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1323547/1323547-1495717017-260.jpg',
#  'name': 'Bonavita Suchárek dietní 10ks',
#  'price': '',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1323547-bonavita-sucharek-dietni-10ks'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8cf'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 980000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1329231/1329231-1505138220-260.jpg',
#  'name': 'Ibis Bagety k dopečení 2 ks',
#  'price': '24,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1329231-ibis-bagety-k-dopeceni-2-ks'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8d0'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 982000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1341145/1341145-1529497939-260.jpg',
#  'name': 'Pekárna Kabát Věneček, 3 ks',
#  'price': '49,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1341145-pekarna-kabat-venecek-3-ks'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8d1'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 985000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1332453/1332453-1516967960-260.jpg',
#  'name': 'Merhautovo pekařství Párek klasik/listové těsto',
#  'price': '24,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1332453-merhautovo-pekarstvi-parek-klasik-listove-testo'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8d2'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 987000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1314841/1314841-1501771734-260.jpg',
#  'name': 'Pekárna Brod Veka tuková krájená balená',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1314841-pekarna-brod-veka-tukova-krajena-balena'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8d3'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 989000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/720937/720937-1496220676-260.jpg',
#  'name': '7Days Croissant double vanilka+višeň',
#  'price': '12,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=720937-7days-croissant-double-vanilka-visen'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8d4'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 992000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1316581/1316581-1474992204-260.jpg',
#  'name': 'RACIO Knäckebrot žitný se sezamem',
#  'price': '39,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1316581-racio-knackebrot-zitny-se-sezamem'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8d5'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 994000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1325903/1325903-1504600622-260.jpg',
#  'name': 'Penam České buchtičky s tvarohovou náplní',
#  'price': '34,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1325903-penam-ceske-buchticky-s-tvarohovou-naplni'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8d6'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 996000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1303693/1303693-1458162025-260.jpg',
#  'name': 'Wasa Delicate pšeničný s rozmarýnem a solí',
#  'price': '79,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1303693-wasa-delicate-psenicny-s-rozmarynem-a-soli'}
# {'_id': ObjectId('5bbcb6c9374e2f05c585e8d7'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 17, 998000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1310581/1310581-1494791837-260.jpg',
#  'name': 'Pekárna Kabát Moravský koláč tvaroh',
#  'price': '27,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1310581-pekarna-kabat-moravsky-kolac-tvaroh'}
# {'_id': ObjectId('5bbcb6ca374e2f05c585e8d8'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 18, 1000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1296943/1296943-1501772588-260.jpg',
#  'name': 'Klasa Linecké koláčky',
#  'price': '19,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1296943-klasa-linecke-kolacky'}
# {'_id': ObjectId('5bbcb6ca374e2f05c585e8d9'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 18, 3000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1340989/1340989-1529325977-260.jpg',
#  'name': 'Laura bageta s bylinkovým máslem',
#  'price': '24,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1340989-laura-bageta-s-bylinkovym-maslem'}
# {'_id': ObjectId('5bbcb6ca374e2f05c585e8da'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 18, 5000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/720933/720933-1496220635-260.jpg',
#  'name': '7Days Croissant double vanilka+jahoda',
#  'price': '12,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=720933-7days-croissant-double-vanilka-jahoda'}
# {'_id': ObjectId('5bbcb6ca374e2f05c585e8db'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 18, 7000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1306189/1306189-1496735474-260.jpg',
#  'name': 'Santa Maria Tex Mex Mexická pšeničná tortilla 24cm 6ks',
#  'price': '76,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1306189-santa-maria-tex-mex-mexicka-psenicna-tortilla-24cm-6ks'}
# {'_id': ObjectId('5bbcb6ca374e2f05c585e8dc'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 18, 9000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1333499/1333499-1516089323-260.jpg',
#  'name': 'DoDo Dalamánky bezlepkové 2 ks',
#  'price': '59,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1333499-dodo-dalamanky-bezlepkove-2-ks'}
# {'_id': ObjectId('5bbcb6ca374e2f05c585e8dd'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 18, 11000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1308399/1308399-1496735666-260.jpg',
#  'name': 'Santa Maria Tex Mex Tortilla placky z celozrnné mouky 20cm 8ks',
#  'price': '79,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1308399-santa-maria-tex-mex-tortilla-placky-z-celozrnne-mouky-20cm-8ks'}
# {'_id': ObjectId('5bbcb6ca374e2f05c585e8de'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 18, 13000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1303695/1303695-1495643411-260.jpg',
#  'name': 'Marlenka medové kuličky',
#  'price': '119,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1303695-marlenka-medove-kulicky'}
# {'_id': ObjectId('5bbcb6ca374e2f05c585e8df'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 18, 15000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1339011/1339011-1524745491-260.jpg',
#  'name': 'Merhautovo pekařství Hamburgerová bulka mléčná se sezamem - malá',
#  'price': '10,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1339011-merhautovo-pekarstvi-hamburgerova-bulka-mlecna-se-sezamem-mala'}
# {'_id': ObjectId('5bbcb6ca374e2f05c585e8e0'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 18, 18000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1314819/1314819-1495631771-260.jpg',
#  'name': 'Pekárna Brod Chléb žitno-pšeničný',
#  'price': '24,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1314819-pekarna-brod-chleb-zitno-psenicny'}
# {'_id': ObjectId('5bbcb6ca374e2f05c585e8e1'),
#  'created_at': datetime.datetime(2018, 10, 9, 14, 10, 18, 20000),
#  'image_url': 'https://cdn.rohlik.cz/images/grocery/products/1330949/1330949-1509355644-260.jpg',
#  'name': 'Pekárna Kabát Tmavá bageta speciál',
#  'price': '54,90\xa0Kč',
#  'url': '/c300101000-pekarna-a-cukrarna?productPopup=1330949-pekarna-kabat-tmava-bageta-special'}

# %%
disc_nr = "21,90\u00a0K\u010d"

# %%
price = [int(s) for s in list(price) if s.isdigit()]
price = (int("".join(map(str, price))))/100

# %%
disc_nr/100
# Out:
# 21.9
